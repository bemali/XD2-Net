# %%
#Mounting on co-lab
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.insert(0,'/content/drive/My Drive/Interpretable_DNN/Revision') # change folder name
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Import of Libaries

import os
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import math
import itertools
import pickle
from numpy.ma.core import argmax

#Model Building and Explanations
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, backend, Model, callbacks
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.regularizers import l2
from sklearn.metrics import confusion_matrix, classification_report,roc_auc_score
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go


#plots
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go



#custom functions
from functions.data_proc import *
from functions.experiment_setup import *
from functions.generate_inputs import *
from functions.model import *

# %% [markdown]
# ### Experiment

# %%
#Experimental parameters
prediction = 'Outcome' 
experiment =  'AG' #'AG_LS' #'AG','MS', 'IX'
timelapsed = 'total'


#Directories
MY_WORKSPACE_DIR = "/content/drive/My Drive/Interpretable_DNN/Revision/BPIC12"
MILESTONE_DIR = MY_WORKSPACE_DIR+'/'+experiment+'/'

#Dataset
file_name = os.path.join(MY_WORKSPACE_DIR,'BPIC_2012_OUTCOME.csv')
log_name = 'BPIC_2012'


#saving parameters to a dictionary
args = get_parameters(MILESTONE_DIR, MY_WORKSPACE_DIR, prediction, experiment, file_name, log_name,None)

# %%
### feature categories
cat_dynamic = ['ACTIVITY','ROLE']
num_dynamic = ['TASK_DURATION','TIME_ELAPSED'] 
cat_static = [] 
num_static = ['AMOUNT_REQ']
activity_name = 'ACTIVITY'

# %% [markdown]
# ### Loading Model Explanations, Pre-processing and Saving

# %%
#files

#model explanations
file_explanations = os.path.join(MILESTONE_DIR,log_name+'_'+experiment+'_explanations.csv')

#LR explanations
file_explanations_LR = os.path.join(MILESTONE_DIR,os.path.join('EVAL',log_name+'_'+experiment+'_LR_explanations.csv'))

#DL explanations
file_explanations_DL = os.path.join(MILESTONE_DIR,os.path.join('EVAL',log_name+'_'+experiment+'_DL_explanations.csv'))

#loading dataframes

#model explanations
df_explanations = pd.read_csv(file_explanations).reset_index(drop = True)
df_explanations = df_explanations.iloc[:,1:]

#LR explanations
df_explanations_LR = pd.read_csv(file_explanations_LR).reset_index(drop = True)
df_explanations_LR = df_explanations_LR.iloc[:,1:]


#DL explanations
df_explanations_DL = pd.read_csv(file_explanations_DL).reset_index(drop = True)
df_explanations_DL = df_explanations_DL.iloc[:,1:]
df_explanations_DL['ACTIVITY_INDEX'] = df_explanations_DL['FEATURE'].str.split().str[-1].astype(int)

# %%
#predictions

#model predictions
file_predictions = os.path.join(MILESTONE_DIR,log_name+'_'+experiment+'_predictions.csv')

#DL predictions
file_predictions_DL = os.path.join(MILESTONE_DIR,os.path.join('EVAL',log_name+'_'+experiment+'_DL_predictions.csv'))

#loading dataframes

#model predictions
df_predictions = pd.read_csv(file_predictions).reset_index(drop = True)
df_predictions = df_predictions.iloc[:,1:]


#DL predictions
df_predictions_DL = pd.read_csv(file_predictions_DL).reset_index(drop = True)
df_predictions_DL = df_predictions_DL.iloc[:,1:]

# %%
df_explanations = df_explanations.merge(df_predictions, on = ['BUCKET','CASEID'])
df_explanations_DL = df_explanations_DL.merge(df_predictions_DL, on = ['BUCKET','CASEID'])

# %%
df_test = pd.read_csv(MY_WORKSPACE_DIR+'/BPIC_2012_log_df_test.csv')
df_test_attributes = df_test[['CASEID','BUCKET','AMOUNT_REQ','TIME_ELAPSED','TASK_DURATION']]

df_amount = df_test.groupby(['BUCKET','CASEID'])['AMOUNT_REQ'].mean().reset_index()
df_time_elapsed = df_test.groupby(['BUCKET','CASEID'])['TIME_ELAPSED'].max().reset_index()
df_task_duration = df_test.groupby(['BUCKET','CASEID'])['TASK_DURATION'].mean().reset_index()

df_test_attributes = df_amount.merge(df_time_elapsed, on = ['BUCKET','CASEID'])
df_test_attributes = df_test_attributes.merge(df_task_duration, on = ['BUCKET','CASEID'])

# %%
df_test_attributes_event = df_test[['BUCKET','CASEID','AMOUNT_REQ','TIME_ELAPSED','TASK_DURATION','ACTIVITY_INDEX']].drop_duplicates()

# %%
#saving the explanations
#local_case_level
df_explanations = df_explanations.merge(df_test_attributes, on = ['BUCKET','CASEID'])
df_explanations.to_csv(MILESTONE_DIR+'/bpic_2012_local_case_level.csv', index = False)

#local_event_level
df_explanations_DL = df_explanations_DL.merge(df_test_attributes_event, on = ['BUCKET','CASEID','ACTIVITY_INDEX'])
df_explanations_DL.to_csv(MILESTONE_DIR+'/bpic_2012_local_event_level.csv', index = False)

# %% [markdown]
# ### Visualization of Explanations

# %%
#Global Explanations

bucket = '1_5'



local_case_level = df_explanations.loc[df_explanations['BUCKET'] == bucket]
global_case_level = df_explanations_LR.loc[df_explanations_LR['BUCKET'] == bucket]
global_case_level_mean = local_case_level.groupby('FEATURE')['FEATURE_IMPORTANCE'].mean().reset_index()
global_case_level_median = local_case_level.groupby('FEATURE')['FEATURE_IMPORTANCE'].median().reset_index()

fig, axes = plt.subplots(1,3,figsize=(12,8))
df_t = local_case_level.copy()
df_t2 = global_case_level.copy()

sn.barplot(data=global_case_level ,y='FEATURE',x = 'FEATURE_IMPORTANCE', 
           palette=['#66cc99' if v < 0 else '#ff3333' for v in global_case_level['FEATURE_IMPORTANCE']], ax = axes[0], width = 0.9)
axes[0].set_yticklabels(global_case_level['FEATURE'], rotation=0,fontsize=12)
axes[0].set_title('Logistic Regression',fontsize=12)
axes[0].set(ylabel= None)
axes[0].set(xlabel= None)
axes[0].set_xlim([-2, 2])


sn.barplot(data=global_case_level_mean ,y='FEATURE',x = 'FEATURE_IMPORTANCE', 
           palette=['#66cc99' if v < 0 else '#ff3333' for v in global_case_level_mean['FEATURE_IMPORTANCE']], ax = axes[1], width = 0.9)
axes[1].set(yticklabels=[])
axes[1].set(ylabel= None)
axes[1].set(xlabel= None)
axes[1].set_title("XD\u00b2-Net: mean aggregated",fontsize=12)
axes[1].set_xlim([-2, 2])

sn.barplot(data=global_case_level_median ,y='FEATURE',x = 'FEATURE_IMPORTANCE', 
           palette=['#66cc99' if v < 0 else '#ff3333' for v in global_case_level_median['FEATURE_IMPORTANCE']], ax = axes[2], width = 0.9)
axes[2].set(yticklabels=[])
axes[2].set(ylabel= None)
axes[2].set(xlabel= None)
axes[2].set_title("XD\u00b2-Net: median aggregated",fontsize=12)
axes[2].set_xlim([-2, 2])

fig.suptitle('Global Explanation',fontsize=14)

# Adjust the subplot spacing


plt.show()

# %%
#Global Explanations

bucket = '1_15'



local_case_level = df_explanations.loc[df_explanations['BUCKET'] == bucket]
global_case_level = df_explanations_LR.loc[df_explanations_LR['BUCKET'] == bucket]
global_case_level_mean = local_case_level.groupby('FEATURE')['FEATURE_IMPORTANCE'].mean().reset_index()
global_case_level_median = local_case_level.groupby('FEATURE')['FEATURE_IMPORTANCE'].median().reset_index()

fig, axes = plt.subplots(1,3,figsize=(12,8))
df_t = local_case_level.copy()
df_t2 = global_case_level.copy()

sn.barplot(data=global_case_level ,y='FEATURE',x = 'FEATURE_IMPORTANCE', 
           palette=['#66cc99' if v < 0 else '#ff3333' for v in global_case_level['FEATURE_IMPORTANCE']], ax = axes[0], width = 0.9)
axes[0].set_yticklabels(global_case_level['FEATURE'], rotation=0,fontsize=12)
axes[0].set_title('Logistic Regression',fontsize=12)
axes[0].set(ylabel= None)
axes[0].set(xlabel= None)
axes[0].set_xlim([-3, 3])


sn.barplot(data=global_case_level_mean ,y='FEATURE',x = 'FEATURE_IMPORTANCE', 
           palette=['#66cc99' if v < 0 else '#ff3333' for v in global_case_level_mean['FEATURE_IMPORTANCE']], ax = axes[1], width = 0.9)
axes[1].set(yticklabels=[])
axes[1].set(ylabel= None)
axes[1].set(xlabel= None)
axes[1].set_title("XD\u00b2-Net: mean aggregated",fontsize=12)
axes[1].set_xlim([-3, 3])

sn.barplot(data=global_case_level_median ,y='FEATURE',x = 'FEATURE_IMPORTANCE', 
           palette=['#66cc99' if v < 0 else '#ff3333' for v in global_case_level_median['FEATURE_IMPORTANCE']], ax = axes[2], width = 0.9)
axes[2].set(yticklabels=[])
axes[2].set(ylabel= None)
axes[2].set(xlabel= None)
axes[2].set_title("XD\u00b2-Net: median aggregated",fontsize=12)
axes[2].set_xlim([-3, 3])

fig.suptitle('Global Explanation',fontsize=14)

# Adjust the subplot spacing


plt.show()

# %%
bucket = '1_5'




global_case_level = df_explanations_LR.loc[df_explanations_LR['BUCKET'] == bucket]
global_case_level.loc[:,'FEATURE_IMPORTANCE_ABS'] = global_case_level['FEATURE_IMPORTANCE'].abs()
global_case_level = global_case_level.sort_values('FEATURE_IMPORTANCE_ABS', ascending = False)


fig, ax= plt.subplots(figsize=(6,8))


sn.barplot(data=global_case_level ,y='FEATURE',x = 'FEATURE_IMPORTANCE', 
           palette=['#66cc99' if v < 0 else '#ff3333' for v in global_case_level['FEATURE_IMPORTANCE']], ax = ax, width = 0.9)
ax.set_yticklabels(global_case_level['FEATURE'], rotation=0,fontsize=12)
ax.set(ylabel= None)
ax.set(xlabel= None)
ax.set_xlim([-3, 3])



plt.show()
# Out:
# <ipython-input-28-9e46245f6168>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   global_case_level.loc[:,'FEATURE_IMPORTANCE_ABS'] = global_case_level['FEATURE_IMPORTANCE'].abs()

# %%
bucket = '1_15'




global_case_level = df_explanations_LR.loc[df_explanations_LR['BUCKET'] == bucket]
global_case_level.loc[:,'FEATURE_IMPORTANCE_ABS'] = global_case_level['FEATURE_IMPORTANCE'].abs()
global_case_level = global_case_level.sort_values('FEATURE_IMPORTANCE_ABS', ascending = False)


fig, ax= plt.subplots(figsize=(6,8))


sn.barplot(data=global_case_level ,y='FEATURE',x = 'FEATURE_IMPORTANCE', 
           palette=['#66cc99' if v < 0 else '#ff3333' for v in global_case_level['FEATURE_IMPORTANCE']], ax = ax, width = 0.9)
ax.set_yticklabels(global_case_level['FEATURE'], rotation=0,fontsize=12)
ax.set(ylabel= None)
ax.set(xlabel= None)
ax.set_xlim([-3, 3])



plt.show()
# Out:
# <ipython-input-33-c0bb6342f3e1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   global_case_level.loc[:,'FEATURE_IMPORTANCE_ABS'] = global_case_level['FEATURE_IMPORTANCE'].abs()

# %%
#Distribution of Predictions
#XD2 Net

buckets = ['1_5','1_10','1_15','1_20']
fig,axes = plt.subplots(1,4 ,figsize = (20,5))
for i,bucket in enumerate(buckets):
  df_t = df_predictions.loc[df_predictions['BUCKET']== bucket]
  sn.histplot(data = df_t, x = 'PREDICTION_PROB',ax = axes[i])

plt.show()

# %%
#Deep Learning
buckets = ['1_5','1_10','1_15','1_20']
fig,axes = plt.subplots(1,4 ,figsize = (20,5))
for i,bucket in enumerate(buckets):
  df_t = df_predictions_DL.loc[df_predictions['BUCKET']== bucket]
  sn.histplot(data = df_t, x = 'PREDICTION_PROB',ax = axes[i])

plt.show()

# %%
#overlap between the XD2 net and DL models
df_temp = df_predictions[['CASEID','BUCKET','PREDICTION_PROB']].merge(df_predictions_DL[['CASEID','BUCKET','PREDICTION_PROB','GROUND_TRUTH']], on = ['CASEID','BUCKET'])
df_temp.columns = ['CASEID','BUCKET','PREDICTION_PROB_XD2_Net','PREDICTION_PROB_DL','GROUND_TRUTH']


sn.scatterplot(data =df_temp, x='PREDICTION_PROB_XD2_Net', y ='PREDICTION_PROB_DL', hue ='GROUND_TRUTH' )
# Out:
# <Axes: xlabel='PREDICTION_PROB_XD2_Net', ylabel='PREDICTION_PROB_DL'>

# %%
df_temp.to_csv(MILESTONE_DIR+'/bpic_2012_cases.csv', index = False)

# %% [markdown]
# ### Evaluation of Global Explanations - Effective Complexity and Feature Agreement

# %% [markdown]
# #### Feature Agreement
#
# https://doi.org/10.48550/arXiv.2202.01602

# %% [markdown]
# ###### Specify Buckets

# %%
#Specify the buckets for which we do the evaluation
buckets = ['1_5','1_10','1_15','1_20'] #['1_5','1_10','1_15','1_20']

# %% [markdown]
# ###### Iterate over buckets - Feature agreement and Rank agreement

# %%
color_list = ['#2168D1','#37BB47']

for bucket in buckets:
  local_case_level = df_explanations.loc[df_explanations['BUCKET'] == bucket]
  global_case_level = df_explanations_LR.loc[df_explanations_LR['BUCKET'] == bucket]

  #specify three levels of aggregation of local case level explanations to global explanation
  global_case_level_ag_mean = local_case_level.groupby(['BUCKET','FEATURE'])['FEATURE_IMPORTANCE'].mean().reset_index()
  global_case_level_ag_median = local_case_level.groupby(['BUCKET','FEATURE'])['FEATURE_IMPORTANCE'].median().reset_index()
  global_case_level_ag_max = local_case_level.groupby(['BUCKET','FEATURE'])['FEATURE_IMPORTANCE'].max().reset_index()

  #rank the features based on the feature importance
  global_case_level.loc[:,'RANK'] = global_case_level['FEATURE_IMPORTANCE'].rank(method = 'dense', ascending = False)
  global_case_level_ag_mean.loc[:,'RANK'] = global_case_level_ag_mean['FEATURE_IMPORTANCE'].rank(method = 'dense', ascending = False)
  global_case_level_ag_median.loc[:,'RANK'] = global_case_level_ag_median['FEATURE_IMPORTANCE'].rank(method = 'dense', ascending = False)
  global_case_level_ag_max.loc[:,'RANK'] = global_case_level_ag_max['FEATURE_IMPORTANCE'].rank(method = 'dense', ascending = False)

  #Feature agreement
  fig, axes = plt.subplots(1,2,figsize=(10,5))

  for j, df in enumerate([global_case_level_ag_mean,global_case_level_ag_median]): 

    titles = ['XD2 net (mean)','XD2 net (median)']
    feature_agreement = []
    top_k_features = list(range(1,6))

    for i in range(5):
      df_t = df.loc[df['RANK'] <=i+1]
      df_t2 = global_case_level.loc[global_case_level['RANK']<=i+1]
      df_t = df_t.merge(df_t2, on = 'FEATURE')
      feature_agreement.append(len(df_t)/(i+1))

      #plot
    sn.barplot(y=feature_agreement ,x = top_k_features , color = color_list[j], ax = axes[j])
    axes[j].set_xticklabels(top_k_features, fontsize = 12)
    #axes[j].set_title(titles[j],fontsize=14)
    axes[j].set_ylim([0, 1])

  fig.suptitle('Feature agreement (Prediction Point '+ bucket.split('_')[1]+')',fontsize=16)
  plt.show()

  #Rank agreement
  fig, axes = plt.subplots(1,2,figsize=(10,5))

  for j, df in enumerate([global_case_level_ag_mean,global_case_level_ag_median]): 

    titles = ['XD2 net (mean)','XD2 net (median)']
    feature_agreement = []
    top_k_features = list(range(1,6))

    for i in range(5):
      df_t = df.loc[df['RANK'] <=i+1]
      df_t2 = global_case_level.loc[global_case_level['RANK']<=i+1]
      df_t = df_t.merge(df_t2, on = ['FEATURE','RANK'])
      feature_agreement.append(len(df_t)/(i+1))

      #plot
    sn.barplot(y=feature_agreement ,x = top_k_features , color = color_list[j], ax = axes[j])
    axes[j].set_xticklabels(top_k_features, fontsize = 12)
    #axes[j].set_title(titles[j],fontsize=14)
    axes[j].set_ylim([0, 1])
  
  fig.suptitle('Rank agreement (Prediction Point '+ bucket.split('_')[1]+')',fontsize=16)
  plt.show()
# Out:
# <ipython-input-23-3dcce4c290dd>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   global_case_level.loc[:,'RANK'] = global_case_level['FEATURE_IMPORTANCE'].rank(method = 'dense', ascending = False)
# <ipython-input-23-3dcce4c290dd>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   global_case_level.loc[:,'RANK'] = global_case_level['FEATURE_IMPORTANCE'].rank(method = 'dense', ascending = False)
# <ipython-input-23-3dcce4c290dd>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   global_case_level.loc[:,'RANK'] = global_case_level['FEATURE_IMPORTANCE'].rank(method = 'dense', ascending = False)
# <ipython-input-23-3dcce4c290dd>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   global_case_level.loc[:,'RANK'] = global_case_level['FEATURE_IMPORTANCE'].rank(method = 'dense', ascending = False)

# %% [markdown]
# #### Effective Complexity

# %% [markdown]
# ###### Specify Buckets

# %%
#Specify the buckets for which we do the evaluation
buckets = ['1_5','1_10','1_15','1_20']
n_sizes = [5,10,15,20]

# %% [markdown]
# ###### Generate model inputs

# %%
#For this evaluation we will require to load the feature vectors in each of these buckets and generate inputs
with open(args['processed_vec'], 'rb') as fp:
    full_vec = pickle.load(fp)

with open(args['indexes'], 'rb') as fp:
    indexes = pickle.load(fp)

with open(args['bucket_info'], 'rb') as fp:
    bucket_info = pickle.load(fp)

inputs_outputs = {} #Final Dictionary with Test and Train Inputs/ Outputs for all buckets

for i in range(len(buckets)):

  vec_train = full_vec[buckets[i]]['vec_train']
  vec_test = full_vec[buckets[i]]['vec_test']

  #removing amt_req feature

  #vec_train['statics']['amt_req'] =  np.absolute(vec_train['statics']['amt_req'])*0
  #vec_test['statics']['amt_req'] =  np.absolute(vec_test['statics']['amt_req'])*0
  

  bucket = buckets[i]
  bucket_inputs_outputs  = {}

  #Inputs and Outputs -- select depending on the encoding technique
  
  inputs_train, outputs_train, input_exp_dim_train, features_exp_train = generate_inputs_AG(vec_train,indexes[bucket],n_sizes[i],cat_dynamic, num_dynamic,cat_static,num_static)
  inputs_test, outputs_test, input_exp_dim_test, features_exp_test = generate_inputs_AG(vec_test,indexes[bucket],n_sizes[i],cat_dynamic, num_dynamic,cat_static,num_static)


  features_exp = features_exp_train
  input_exp_dim = input_exp_dim_train
  if len(features_exp_test) > len(features_exp_train):
    features_exp = features_exp_test
    input_exp_dim = input_exp_dim_test

    #if training feature dimensionality < test feature dimensionalty, reshape the training feature dimensionality (this can happen when sample size is too small)
    input_exp_temp =[]
    for i in range(inputs_train['input_exp'].shape[0]):
      feat =[]
      k = 0
      for j in range(len(features_exp)):
        if features_exp[j] == features_exp_train[k]:
          feat.append(inputs_train['input_exp'][i][k])
          k = k+1
        else:
          feat.append(0)
      input_exp_temp.append(feat)
    input_exp_temp = np.asarray(input_exp_temp) 
    inputs_train['input_exp'] = input_exp_temp

  if len(features_exp_test) < len(features_exp_train):
    #if test feature dimensionality < training feature dimensionalty, reshape the test feature dimensionality (this can happen when sample size is too small)
    input_exp_temp =[]
    for i in range(inputs_test['input_exp'].shape[0]):
      feat =[]
      k = 0
      for j in range(len(features_exp)):
        if features_exp[j] == features_exp_test[k]:
          feat.append(inputs_test['input_exp'][i][k])
          k = k+1
        else:
          feat.append(0)
      input_exp_temp.append(feat)
    input_exp_temp = np.asarray(input_exp_temp) 
    inputs_test['input_exp'] = input_exp_temp

  bucket_inputs_outputs['inputs_train'] = inputs_train
  bucket_inputs_outputs['inputs_test'] = inputs_test
  bucket_inputs_outputs['outputs_train'] = outputs_train
  bucket_inputs_outputs['outputs_test'] = outputs_test
  bucket_inputs_outputs['explainable_feature_names'] = features_exp
  bucket_inputs_outputs['input_exp_dim'] = input_exp_dim

  inputs_outputs[bucket] = bucket_inputs_outputs
  
  dynamic_dim = bucket_inputs_outputs['inputs_train']['input_dynamic'].shape[2]
  try: static_dim = bucket_inputs_outputs['inputs_train']['input_static'].shape[1]
  except: static_dim  = 1

  print(bucket+' done!')
  print(inputs_train['input_dynamic'].shape)
  print(static_dim)
  print(input_exp_dim)
# Out:
# 1_5 done!
# (3130, 5, 15)
# 1
# 16
# 1_10 done!
# (3130, 10, 20)
# 1
# 21
# 1_15 done!
# (2276, 15, 21)
# 1
# 22
# 1_20 done!
# (1240, 20, 21)
# 1
# 22

# %% [markdown]
# ###### Iterate over buckets

# %%
epsilon = 0.5
prefix_bucket_XD2 = []
effective_complexity_XD2 = []
rmse_XD2 = []
prefix_bucket_LR = []
effective_complexity_LR = []
rmse_LR = []

for bucket in buckets:

  local_case_level = df_explanations.loc[df_explanations['BUCKET'] == bucket]
  global_case_level = df_explanations_LR.loc[df_explanations_LR['BUCKET'] == bucket]

  #get the order of the inputs
  global_exp_LR = global_case_level.groupby('FEATURE')['FEATURE_IMPORTANCE'].mean().reset_index()
  global_exp_XD2_net = local_case_level.groupby('FEATURE')['FEATURE_IMPORTANCE'].median().reset_index()

  #rank the features based on the absolute feature importance
  global_exp_LR['RANK'] = global_exp_LR['FEATURE_IMPORTANCE'].abs().rank()
  global_exp_XD2_net['RANK'] = global_exp_XD2_net['FEATURE_IMPORTANCE'].abs().rank()

  #generate a dataframe with the correct order of features and ranks
  features_exp = inputs_outputs[bucket]['explainable_feature_names']
  df_feature_ranks = pd.DataFrame({'FEATURE':features_exp})
  df_feature_ranks = df_feature_ranks.merge(global_exp_LR[['FEATURE','RANK']], on = 'FEATURE')
  df_feature_ranks.columns = ['FEATURE','LR_RANK']
  df_feature_ranks = df_feature_ranks.merge(global_exp_XD2_net[['FEATURE','RANK']], on = 'FEATURE')

  #load inputs outputs
  input_test = inputs_outputs[bucket]['inputs_test']
  output_test = inputs_outputs[bucket]['outputs_test']
  input_train = inputs_outputs[bucket]['inputs_train']
  output_train = inputs_outputs[bucket]['outputs_train']
  exp_dim = input_test['input_exp'].shape[1]

  #Evaluation for XD2 Net----------------------------------------------------------------------------------------------------------------

  #load original model
  model_XD_file =  os.path.join(MILESTONE_DIR,'_model_'+ bucket +'.pkl')
  with open(model_XD_file, 'rb') as f:
    xd_model = pickle.load(f)

  #original output
  y_pred_original =  xd_model.predict([input_test['input_dynamic'],input_test['input_static'],input_test['input_exp']])[1].flatten()


  
  #iterate over features 
  for i in range(len(features_exp)-1):

    indexes = list(df_feature_ranks[df_feature_ranks['RANK'] <= i+1].index)
    dynamic_indexes = [x for x in indexes if x < input_train['input_dynamic'].shape[2]]
    static_indexes = [input_train['input_dynamic'].shape[2]-x for x in indexes if x >= input_train['input_dynamic'].shape[2]]


    #delete the least significant features
    input_train_exp_temp = np.delete(input_train['input_exp'], indexes, axis=1)
    input_test_exp_temp = np.delete(input_test['input_exp'], indexes, axis=1)

    input_train_dynamic_temp = np.delete(input_train['input_dynamic'], dynamic_indexes, axis=2)
    input_test_dynamic_temp = np.delete(input_test['input_dynamic'], dynamic_indexes, axis=2)

    input_train_static_temp = np.delete(input_train['input_static'], static_indexes, axis=1)
    input_test_static_temp = np.delete(input_test['input_static'], static_indexes, axis=1)

    if input_train_dynamic_temp.shape[2] == 0:
      print('XD2_Net fails')
      break
    else:    
    
        #create new inputs with ablated features
        input_test_temp = {'input_dynamic': input_test_dynamic_temp,'input_static': input_test_static_temp, 'input_exp': input_test_exp_temp}
        input_train_temp = {'input_dynamic': input_train_dynamic_temp,'input_static': input_train_static_temp, 'input_exp': input_train_exp_temp}

        #build and train new models for the new inputs
        lstm_size_alpha = 70
        lstm_size_beta = 70
        dense_1_dim = 1.5
        learning_rate = 0.01
        max_len = input_train_temp['input_dynamic'].shape[1]

        self_explainable_temp = self_explainable_model(args, max_len, input_train_temp ,lstm_size_alpha, lstm_size_beta, dense_1_dim, learning_rate )

        #Train Model
        batch_size = 256 # 32, 64, 128, 256
        epochs = 100
        input_train = inputs_outputs[bucket]['inputs_train']
        output_train = inputs_outputs[bucket]['outputs_train']
        model_history = self_explainable_model_fit(input_train_temp,output_train,args, self_explainable_temp, MY_WORKSPACE_DIR, batch_size, epochs)

        #make the new prediction
        y_pred_temp = self_explainable_temp.predict([input_test_temp['input_dynamic'],input_test_temp['input_static'],input_test_temp['input_exp']])[1].flatten()
        rmse = np.sqrt(mean_squared_error(y_pred_original, y_pred_temp))

        prefix_bucket_XD2.append(bucket)
        effective_complexity_XD2.append(len(features_exp)-(i+1))
        rmse_XD2.append(rmse)

        if rmse >= epsilon:
          break

  


  #Evaluation for LR Model----------------------------------------------------------------------------------------------------------------
  #load original model
  model_LR_file =  os.path.join(MILESTONE_DIR+'/EVAL','_LR_model_'+ bucket +'.pkl')
  with open(model_LR_file, 'rb') as f:
    lr_model = pickle.load(f)

  y_pred_original_lr = lr_model.predict(input_test['input_exp']).flatten()


  

  #iterate over features 
  for i in range(len(features_exp)-1):
    indexes = list(df_feature_ranks[df_feature_ranks['LR_RANK'] <= i+1].index)

    #delete the least significant features
    input_train_exp_temp = np.delete(input_train['input_exp'], indexes, axis=1)
    input_test_exp_temp = np.delete(input_test['input_exp'], indexes, axis=1)

    #build and train new models for the new inputs

    lr_temp = LogisticRegression(random_state=0,max_iter=1000).fit(input_train_exp_temp, output_train['act_output'])
    y_pred_temp = lr_temp.predict(input_test_exp_temp)
    rmse = np.sqrt(mean_squared_error(y_pred_original_lr, y_pred_temp))

    prefix_bucket_LR.append(bucket)
    effective_complexity_LR.append(len(features_exp)-(i+1))
    rmse_LR.append(rmse)

    if rmse >= epsilon:
      break

df_xd2_net_effective_complexity = pd.DataFrame({'BUCKET':prefix_bucket_XD2,'COMPLEXITY':effective_complexity_XD2, 'ERROR': rmse_XD2})
df_xd2_net_effective_complexity.to_csv(os.path.join(MILESTONE_DIR,os.path.join('EVAL',log_name+'_effective_complexity_XD2_net_median.csv')))

df_LR_effective_complexity = pd.DataFrame({'BUCKET':prefix_bucket_LR,'COMPLEXITY':effective_complexity_LR, 'ERROR': rmse_LR})
df_LR_effective_complexity.to_csv(os.path.join(MILESTONE_DIR,os.path.join('EVAL',log_name+'_effective_complexity_LR.csv')))
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 10/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6470 - act_output_loss: 0.6465 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.5760 - val_loss: 0.6724 - val_act_output_loss: 0.6719 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.5029 - lr: 0.0100
# Epoch 11/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6407 - act_output_loss: 0.6402 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.5977 - val_loss: 0.6608 - val_act_output_loss: 0.6603 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.5497 - lr: 0.0100
# Epoch 12/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6335 - act_output_loss: 0.6329 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6396 - val_loss: 0.6480 - val_act_output_loss: 0.6473 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.5877 - lr: 0.0100
# Epoch 13/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6262 - act_output_loss: 0.6255 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6691 - val_loss: 0.6366 - val_act_output_loss: 0.6358 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6140 - lr: 0.0100
# Epoch 14/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6189 - act_output_loss: 0.6180 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6820 - val_loss: 0.6245 - val_act_output_loss: 0.6235 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6667 - lr: 0.0100
# Epoch 15/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6095 - act_output_loss: 0.6084 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6975 - val_loss: 0.6141 - val_act_output_loss: 0.6129 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6988 - lr: 0.0100
# Epoch 16/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6000 - act_output_loss: 0.5987 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7151 - val_loss: 0.6017 - val_act_output_loss: 0.6003 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7222 - lr: 0.0100
# Epoch 17/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5878 - act_output_loss: 0.5864 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7394 - val_loss: 0.5905 - val_act_output_loss: 0.5890 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7222 - lr: 0.0100
# Epoch 18/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5797 - act_output_loss: 0.5781 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7518 - val_loss: 0.5842 - val_act_output_loss: 0.5824 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7368 - lr: 0.0100
# Epoch 19/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5726 - act_output_loss: 0.5706 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7513 - val_loss: 0.5776 - val_act_output_loss: 0.5753 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7456 - lr: 0.0100
# Epoch 20/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5620 - act_output_loss: 0.5596 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7549 - val_loss: 0.5662 - val_act_output_loss: 0.5637 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7485 - lr: 0.0100
# Epoch 21/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5542 - act_output_loss: 0.5516 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7575 - val_loss: 0.5606 - val_act_output_loss: 0.5580 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7573 - lr: 0.0100
# Epoch 22/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5452 - act_output_loss: 0.5426 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7642 - val_loss: 0.5565 - val_act_output_loss: 0.5539 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7573 - lr: 0.0100
# Epoch 23/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5412 - act_output_loss: 0.5386 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7601 - val_loss: 0.5541 - val_act_output_loss: 0.5515 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7573 - lr: 0.0100
# Epoch 24/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5374 - act_output_loss: 0.5347 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7508 - val_loss: 0.5471 - val_act_output_loss: 0.5444 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7632 - lr: 0.0100
# Epoch 25/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5292 - act_output_loss: 0.5264 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7611 - val_loss: 0.5396 - val_act_output_loss: 0.5368 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7661 - lr: 0.0100
# Epoch 26/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5228 - act_output_loss: 0.5200 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7606 - val_loss: 0.5344 - val_act_output_loss: 0.5315 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7632 - lr: 0.0100
# Epoch 27/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5169 - act_output_loss: 0.5141 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7658 - val_loss: 0.5299 - val_act_output_loss: 0.5270 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7749 - lr: 0.0100
# Epoch 28/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5166 - act_output_loss: 0.5137 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7725 - val_loss: 0.5294 - val_act_output_loss: 0.5265 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7661 - lr: 0.0100
# Epoch 29/100
# 8/8 [==============================] - 0s 22ms/step - loss: 0.5147 - act_output_loss: 0.5117 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7689 - val_loss: 0.5273 - val_act_output_loss: 0.5243 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7719 - lr: 0.0100
# Epoch 30/100
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5058 - act_output_loss: 0.5027 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7715 - val_loss: 0.5277 - val_act_output_loss: 0.5246 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7573 - lr: 0.0100
# Epoch 31/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5032 - act_output_loss: 0.5000 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7735 - val_loss: 0.5167 - val_act_output_loss: 0.5135 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.
100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6184 - act_output_loss: 0.6174 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6934 - val_loss: 0.6255 - val_act_output_loss: 0.6246 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6491 - lr: 0.0100
# Epoch 14/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6097 - act_output_loss: 0.6087 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7156 - val_loss: 0.6143 - val_act_output_loss: 0.6132 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6930 - lr: 0.0100
# Epoch 15/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6034 - act_output_loss: 0.6023 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7239 - val_loss: 0.6020 - val_act_output_loss: 0.6008 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7018 - lr: 0.0100
# Epoch 16/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5964 - act_output_loss: 0.5950 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7342 - val_loss: 0.5925 - val_act_output_loss: 0.5910 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7368 - lr: 0.0100
# Epoch 17/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5892 - act_output_loss: 0.5877 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7373 - val_loss: 0.5847 - val_act_output_loss: 0.5831 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7485 - lr: 0.0100
# Epoch 18/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5790 - act_output_loss: 0.5774 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7503 - val_loss: 0.5827 - val_act_output_loss: 0.5810 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7515 - lr: 0.0100
# Epoch 19/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5709 - act_output_loss: 0.5690 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7513 - val_loss: 0.5800 - val_act_output_loss: 0.5779 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7398 - lr: 0.0100
# Epoch 20/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5610 - act_output_loss: 0.5588 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7565 - val_loss: 0.5654 - val_act_output_loss: 0.5630 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7456 - lr: 0.0100
# Epoch 21/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5499 - act_output_loss: 0.5475 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7668 - val_loss: 0.5583 - val_act_output_loss: 0.5560 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7456 - lr: 0.0100
# Epoch 22/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5386 - act_output_loss: 0.5362 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7689 - val_loss: 0.5551 - val_act_output_loss: 0.5528 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7632 - lr: 0.0100
# Epoch 23/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5303 - act_output_loss: 0.5278 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7709 - val_loss: 0.5448 - val_act_output_loss: 0.5423 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7515 - lr: 0.0100
# Epoch 24/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5206 - act_output_loss: 0.5179 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7802 - val_loss: 0.5360 - val_act_output_loss: 0.5333 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7661 - lr: 0.0100
# Epoch 25/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5149 - act_output_loss: 0.5121 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7782 - val_loss: 0.5350 - val_act_output_loss: 0.5322 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7632 - lr: 0.0100
# Epoch 26/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5065 - act_output_loss: 0.5037 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7802 - val_loss: 0.5299 - val_act_output_loss: 0.5271 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7632 - lr: 0.0100
# Epoch 27/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5033 - act_output_loss: 0.5004 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7854 - val_loss: 0.5250 - val_act_output_loss: 0.5221 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7573 - lr: 0.0100
# Epoch 28/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5018 - act_output_loss: 0.4989 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7875 - val_loss: 0.5193 - val_act_output_loss: 0.5163 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7632 - lr: 0.0100
# Epoch 29/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4941 - act_output_loss: 0.4911 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7901 - val_loss: 0.5232 - val_act_output_loss: 0.5203 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7719 - lr: 0.0100
# Epoch 30/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4882 - act_output_loss: 0.4852 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7927 - val_loss: 0.5250 - val_act_output_loss: 0.5220 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7485 - lr: 0.0100
# Epoch 31/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4850 - act_output_loss: 0.4820 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7875 - val_loss: 0.5247 - val_act_output_loss: 0.5216 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7573 - lr: 0.0100
# Epoch 32/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4802 - act_output_loss: 0.4770 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7927 - val_loss: 0.5176 - val_act_output_loss: 0.5145 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7632 - lr: 0.0100
# Epoch 33/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4823 - act_output_loss: 0.4791 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7916 - val_loss: 0.5317 - val_act_output_loss: 0.5285 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7485 - lr: 0.0100
# Epoch 34/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4729 - act_output_loss: 0.4695 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7994 - val_loss: 0.5239 - val_act_output_loss: 0.5205 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7515 - lr: 0.0100
# Epoch 35/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4721 - act_output_loss: 0.4687 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7896 - val_loss: 0.5214 - val_act_output_loss: 0.5180 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7632 - lr: 0.0100
# Epoch 36/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4676 - act_output_loss: 0.4641 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7983 - val_loss: 0.5196 - val_act_output_loss: 0.5162 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7661 - lr: 0.0100
# Epoch 37/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4602 - act_output_loss: 0.4568 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8061 - val_loss: 0.5207 - val_act_output_loss: 0.5172 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7515 - lr: 0.0100
# Epoch 38/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4537 - act_output_loss: 0.4502 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8077 - val_loss: 0.5272 - val_act_output_loss: 0.5237 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7485 - lr: 0.0100
# Epoch 39/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4506 - act_output_loss: 0.4470 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8170 - val_loss: 0.5257 - val_act_output_loss: 0.5221 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7398 - lr: 0.0100
# Epoch 40/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4460 - act_output_loss: 0.4422 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8139 - val_loss: 0.5222 - val_act_output_loss: 0.5184 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7573 - lr: 0.0100
# Epoch 41/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4436 - act_output_loss: 0.4398 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8201 - val_loss: 0.5176 - val_act_output_loss: 0.5137 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7485 - lr: 0.0100
# Epoch 42/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4374 - act_output_loss: 0.4334 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8185 - val_loss: 0.5213 - val_act_output_loss: 0.5172 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7427 - lr: 0.0100
# Epoch 43/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4237 - act_output_loss: 0.4196 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8263 - val_loss: 0.5226 - val_act_output_loss: 0.5185 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7544 - lr: 0.0050
# Epoch 44/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4146 - act_output_loss: 0.4105 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8392 - val_loss: 0.5217 - val_act_output_loss: 0.5175 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7544 - lr: 0.0050
# Epoch 45/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4106 - act_output_loss: 0.4065 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8418 - val_loss: 0.5193 - val_act_output_loss: 0.5151 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7544 - lr: 0.0050
# Epoch 46/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4042 - act_output_loss: 0.4000 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8438 - val_loss: 0.5248 - val_act_output_loss: 0.5206 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7398 - lr: 0.0050
# Epoch 47/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3990 - act_output_loss: 0.3948 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8464 - val_loss: 0.5230 - val_act_output_loss: 0.5188 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7544 - lr: 0.0050
# Epoch 48/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3945 - act_output_loss: 0.3902 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8526 - val_loss: 0.5244 - val_act_output_loss: 0.5201 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7544 - lr: 0.0050
# Epoch 49/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.3905 - act_output_loss: 0.3862 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8542 - val_loss: 0.5313 - val_act_output_loss: 0.5269 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7485 - lr: 0.0050
# Epoch 50/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3871 - act_output_loss: 0.3827 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8552 - val_loss: 0.5283 - val_act_output_loss: 0.5238 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7515 - lr: 0.0050
# Epoch 51/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3826 - act_output_loss: 0.3781 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8599 - val_loss: 0.5293 - val_act_output_loss: 0.5248 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7427 - lr: 0.0050
# 33/33 [==============================] - 1s 4ms/step
# Epoch 1/100
# 8/8 [==============================] - 10s 216ms/step - loss: 0.8841 - act_output_loss: 0.8826 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.5160 - val_loss: 0.9493 - val_act_output_loss: 0.9487 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.4094 - lr: 0.0100
# Epoch 2/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.7875 - act_output_loss: 0.7871 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.5160 - val_loss: 0.8419 - val_act_output_loss: 0.8418 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.4094 - lr: 0.0100
# Epoch 3/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.7312 - act_output_loss: 0.7311 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.5160 - val_loss: 0.7772 - val_act_output_loss: 0.7771 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.4094 - lr: 0.0100
# Epoch 4/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.7000 - act_output_loss: 0.6999 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.5196 - val_loss: 0.7401 - val_act_output_loss: 0.7400 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.4123 - lr: 0.0100
# Epoch 5/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6860 - act_output_loss: 0.6859 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.5274 - val_loss: 0.7156 - val_act_output_loss: 0.7156 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.4357 - lr: 0.0100
# Epoch 6/100
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6746 - act_output_loss: 0.6746 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.5445 - val_loss: 0.7007 - val_act_output_loss: 0.7007 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.4474 - lr: 0.0100
# Epoch 7/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6670 - act_output_loss: 0.6669 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.5631 - val_loss: 0.6895 - val_act_output_loss: 0.6895 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.4620 - lr: 0.0100
# Epoch 8/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6594 - act_output_loss: 0.6593 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.5765 - val_loss: 0.6819 - val_act_output_loss: 0.6817 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.4795 - lr: 0.0100
# Epoch 9/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6507 - act_output_loss: 0.6504 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.5874 - val_loss: 0.6745 - val_act_output_loss: 0.6740 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.5000 - lr: 0.0100
# Epoch 10/100
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6423 - act_output_loss: 0.6418 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6029 - val_loss: 0.6671 - val_act_output_loss: 0.6664 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.5263 - lr: 0.0100
# Epoch 11/100
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6354 - act_output_loss: 0.6347 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6215 - val_loss: 0.6582 - val_act_output_loss: 0.6574 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.5643 - lr: 0.0100
# Epoch 12/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6278 - act_output_loss: 0.6271 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6417 - val_loss: 0.6467 - val_act_output_loss: 0.6460 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.5936 - lr: 0.0100
# Epoch 13/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6192 - act_output_loss: 0.6183 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6737 - val_loss: 0.6329 - val_act_output_loss: 0.6320 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6228 - lr: 0.0100
# Epoch 14/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6108 - act_output_loss: 0.6099 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6908 - val_loss: 0.6196 - val_act_output_loss: 0.6185 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6579 - lr: 0.0100
# Epoch 15/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6051 - act_output_loss: 0.6039 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7068 - val_loss: 0.6150 - val_act_output_loss: 0.6137 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6842 - lr: 0.0100
# Epoch 16/100
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6017 - act_output_loss: 0.6003 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7130 - val_loss: 0.6054 - val_act_output_loss: 0.6039 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6988 - lr: 0.0100
# Epoch 17/100
# 8/8 [==============================] - 0s 22ms/step - loss: 0.5898 - act_output_loss: 0.5882 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7322 - val_loss: 0.5924 - val_act_output_loss: 0.5908 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7251 - lr: 0.0100
# Epoch 18/100
# 8/8 [==============================] - 0s 22ms/step - loss: 0.5794 - act_output_loss: 0.5777 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7404 - val_loss: 0.5831 - val_act_output_loss: 0.5815 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7339 - lr: 0.0100
# Epoch 19/100
# 8/8 [==============================] - 0s 22ms/step - loss: 0.5727 - act_output_loss: 0.5711 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7404 - val_loss: 0.5738 - val_act_output_loss: 0.5721 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7544 - lr: 0.0100
# Epoch 20/100
# 8/8 [==============================] - 0s 24ms/step - loss: 0.5661 - act_output_loss: 0.5645 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7492 - val_loss: 0.5691 - val_act_output_loss: 0.5675 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7602 - lr: 0.0100
# Epoch 21/100
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5580 - act_output_loss: 0.5563 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7497 - val_loss: 0.5623 - val_act_output_loss: 0.5606 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7485 - lr: 0.0100
# Epoch 22/100
# 8/8 [==============================] - 0s 22ms/step - loss: 0.5522 - act_output_loss: 0.5503 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7477 - val_loss: 0.5546 - val_act_output_loss: 0.5528 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7690 - lr: 0.0100
# Epoch 23/100
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5457 - act_output_loss: 0.5438 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7446 - val_loss: 0.5500 - val_act_output_loss: 0.5480 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7690 - lr: 0.0100
# Epoch 24/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5353 - act_output_loss: 0.5333 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7539 - val_loss: 0.5414 - val_act_output_loss: 0.5394 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7602 - lr: 0.0100
# Epoch 25/100
# 8/8 [==============================] - 0s 22ms/step - loss: 0.5313 - act_output_loss: 0.5293 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7596 - val_loss: 0.5374 - val_act_output_loss: 0.5353 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7632 - lr: 0.0100
# Epoch 26/100
# 8/8 [==============================] - 0s 22ms/step - loss: 0.5261 - act_output_loss: 0.5239 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7632 - val_loss: 0.5319 - val_act_output_loss: 0.5295 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7661 - lr: 0.0100
# Epoch 27/100
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5217 - act_output_loss: 0.5193 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7678 - val_loss: 0.5304 - val_act_output_loss: 0.5280 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7807 - lr: 0.0100
# Epoch 28/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5175 - act_output_loss: 0.5152 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7751 - val_loss: 0.5252 - val_act_output_loss: 0.5229 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7719 - lr: 0.0100
# Epoch 29/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5140 - act_output_loss: 0.5117 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7756 - val_loss: 0.5236 - val_act_output_loss: 0.5213 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7690 - lr: 0.0100
# Epoch 30/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5119 - act_output_loss: 0.5096 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7709 - val_loss: 0.5228 - val_act_output_loss: 0.5205 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7661 - lr: 0.0100
# Epoch 31/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5128 - act_output_loss: 0.5105 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7673 - val_loss: 0.5245 - val_act_output_loss: 0.5221 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7602 - lr: 0.0100
# Epoch 32/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5216 - act_output_loss: 0.5192 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7528 - val_loss: 0.5252 - val_act_output_loss: 0.5228 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7632 - lr: 0.0100
# Epoch 33/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5147 - act_output_loss: 0.5122 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7637 - val_loss: 0.5285 - val_act_output_loss: 0.5260 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7398 - lr: 0.0100
# Epoch 34/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5073 - act_output_loss: 0.5049 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7720 - val_loss: 0.5231 - val_act_output_loss: 0.5206 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7690 - lr: 0.0100
# Epoch 35/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5035 - act_output_loss: 0.5009 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7715 - val_loss: 0.5216 - val_act_output_loss: 0.5191 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7573 - lr: 0.0100
# Epoch 36/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5089 - act_output_loss: 0.5064 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7601 - val_loss: 0.5099 - val_act_output_loss: 0.5074 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7719 - lr: 0.0100
# Epoch 37/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5036 - act_output_loss: 0.5010 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7616 - val_loss: 0.5105 - val_act_output_loss: 0.5079 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7632 - lr: 0.0100
# Epoch 38/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4972 - act_output_loss: 0.4944 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7694 - val_loss: 0.5075 - val_act_output_loss: 0.5046 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7632 - lr: 0.0100
# Epoch 39/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4864 - act_output_loss: 0.4836 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7839 - val_loss: 0.5093 - val_act_output_loss: 0.5063 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7632 - lr: 0.0100
# Epoch 40/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4824 - act_output_loss: 0.4794 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7875 - val_loss: 0.5088 - val_act_output_loss: 0.5057 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7573 - lr: 0.0100
# Epoch 41/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4699 - act_output_loss: 0.4668 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7947 - val_loss: 0.5020 - val_act_output_loss: 0.4989 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7661 - lr: 0.0100
# Epoch 42/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4737 - act_output_loss: 0.4706 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7916 - val_loss: 0.5054 - val_act_output_loss: 0.5022 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7719 - lr: 0.0100
# Epoch 43/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4674 - act_output_loss: 0.4642 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7963 - val_loss: 0.5043 - val_act_output_loss: 0.5011 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7632 - lr: 0.0100
# Epoch 44/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.4608 - act_output_loss: 0.4575 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.7968 - val_loss: 0.4986 - val_act_output_loss: 0.4953 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7602 - lr: 0.0100
# Epoch 45/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4518 - act_output_loss: 0.4483 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8087 - val_loss: 0.5027 - val_act_output_loss: 0.4991 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7749 - lr: 0.0100
# Epoch 46/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.4500 - act_output_loss: 0.4463 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8077 - val_loss: 0.4926 - val_act_output_loss: 0.4888 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7544 - lr: 0.0100
# Epoch 47/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4440 - act_output_loss: 0.4401 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8082 - val_loss: 0.5078 - val_act_output_loss: 0.5038 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7690 - lr: 0.0100
# Epoch 48/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4401 - act_output_loss: 0.4361 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8139 - val_loss: 0.5104 - val_act_output_loss: 0.5063 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7573 - lr: 0.0100
# Epoch 49/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.4349 - act_output_loss: 0.4308 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8185 - val_loss: 0.4988 - val_act_output_loss: 0.4946 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7749 - lr: 0.0100
# Epoch 50/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4254 - act_output_loss: 0.4211 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8226 - val_loss: 0.5009 - val_act_output_loss: 0.4965 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7632 - lr: 0.0100
# Epoch 51/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4193 - act_output_loss: 0.4148 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8309 - val_loss: 0.5000 - val_act_output_loss: 0.4954 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7749 - lr: 0.0100
# Epoch 52/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4130 - act_output_loss: 0.4083 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8325 - val_loss: 0.4963 - val_act_output_loss: 0.4915 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7778 - lr: 0.0100
# Epoch 53/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.4074 - act_output_loss: 0.4024 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8361 - val_loss: 0.4984 - val_act_output_loss: 0.4933 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7690 - lr: 0.0100
# Epoch 54/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4073 - act_output_loss: 0.4021 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.8320 - val_loss: 0.5028 - val_act_output_loss: 0.4975 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.7573 - lr: 0.0100
# Epoch 55/100
# ...
# Epoch 6/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6664 - act_output_loss: 0.6664 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.5958 - val_loss: 0.6660 - val_act_output_loss: 0.6660 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.
- val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6505 - lr: 0.0100
# Epoch 39/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.6566 - act_output_loss: 0.6566 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6139 - val_loss: 0.6473 - val_act_output_loss: 0.6473 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6505 - lr: 0.0100
# Epoch 40/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.6565 - act_output_loss: 0.6565 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6139 - val_loss: 0.6465 - val_act_output_loss: 0.6465 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6559 - lr: 0.0100
# Epoch 41/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6565 - act_output_loss: 0.6565 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6120 - val_loss: 0.6460 - val_act_output_loss: 0.6460 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6613 - lr: 0.0100
# Epoch 42/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.6564 - act_output_loss: 0.6564 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6129 - val_loss: 0.6459 - val_act_output_loss: 0.6459 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6613 - lr: 0.0100
# Epoch 43/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6563 - act_output_loss: 0.6563 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6129 - val_loss: 0.6457 - val_act_output_loss: 0.6457 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6613 - lr: 0.0100
# Epoch 44/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6563 - act_output_loss: 0.6563 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6120 - val_loss: 0.6457 - val_act_output_loss: 0.6457 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6559 - lr: 0.0100
# Epoch 45/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.6563 - act_output_loss: 0.6563 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6120 - val_loss: 0.6464 - val_act_output_loss: 0.6464 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6505 - lr: 0.0100
# Epoch 46/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6561 - act_output_loss: 0.6561 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6139 - val_loss: 0.6472 - val_act_output_loss: 0.6472 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6505 - lr: 0.0100
# Epoch 47/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6561 - act_output_loss: 0.6561 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6120 - val_loss: 0.6479 - val_act_output_loss: 0.6479 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6505 - lr: 0.0100
# Epoch 48/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6562 - act_output_loss: 0.6562 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6053 - val_loss: 0.6484 - val_act_output_loss: 0.6484 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6290 - lr: 0.0100
# Epoch 49/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.6563 - act_output_loss: 0.6563 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6034 - val_loss: 0.6487 - val_act_output_loss: 0.6487 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6290 - lr: 0.0100
# Epoch 50/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6563 - act_output_loss: 0.6563 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6025 - val_loss: 0.6488 - val_act_output_loss: 0.6488 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6290 - lr: 0.0100
# Epoch 51/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.6563 - act_output_loss: 0.6563 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6025 - val_loss: 0.6485 - val_act_output_loss: 0.6485 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6290 - lr: 0.0100
# Epoch 52/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6562 - act_output_loss: 0.6562 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6025 - val_loss: 0.6480 - val_act_output_loss: 0.6480 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6290 - lr: 0.0100
# Epoch 53/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6562 - act_output_loss: 0.6562 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6082 - val_loss: 0.6465 - val_act_output_loss: 0.6465 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6505 - lr: 0.0100
# Epoch 54/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.6560 - act_output_loss: 0.6560 - explanation_weights_accuracy: 0.0000e+00 - act_output_accuracy: 0.6186 - val_loss: 0.6460 - val_act_output_loss: 0.6460 - val_explanation_weights_accuracy: 0.0000e+00 - val_act_output_accuracy: 0.6505 - lr: 0.0050
# 17/17 [==============================] - 1s 4ms/step

# %%
df_xd2_net_effective_complexity
# Out:
#    BUCKET  COMPLEXITY     ERROR
# 0     1_5          15  0.043588
# 1     1_5          14  0.043270
# 2     1_5          13  0.060710
# 3     1_5          12  0.066382
# 4     1_5          11  0.051583
# ..    ...         ...       ...
# 72   1_20           5  0.184706
# 73   1_20           4  0.212552
# 74   1_20           3  0.257540
# 75   1_20           2  0.304276
# 76   1_20           1  0.304172
#
# [77 rows x 3 columns]
